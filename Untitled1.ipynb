# %%
# !pip install Deep-Fake-Detection
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Deep-Fake-Detection
#   Downloading Deep_Fake_Detection-0.0.10-py3-none-any.whl (17 kB)
# Installing collected packages: Deep-Fake-Detection
# Successfully installed Deep-Fake-Detection-0.0.10

# %%
# !sudo pip3 install imageio==2.4.1
from deepfake_detection import DeepFake_Utils
from moviepy.editor import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imageio==2.4.1
#   Downloading imageio-2.4.1.tar.gz (3.3 MB)
#      |████████████████████████████████| 3.3 MB 14.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from imageio==2.4.1) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio==2.4.1) (7.1.2)
# Building wheels for collected packages: imageio
#   Building wheel for imageio (setup.py) ... done
#   Created wheel for imageio: filename=imageio-2.4.1-py3-none-any.whl size=3303885 sha256=8765831f010ea507af9f0350729f026241c025d56a53b538c1a03afc5d9a21b6
#   Stored in directory: /root/.cache/pip/wheels/46/20/07/7bb9c8c44e6ec2efa60fd0e6280094f53f65f41767ef69a5ee
# Successfully built imageio
# Installing collected packages: imageio
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.9.0
#     Uninstalling imageio-2.9.0:
#       Successfully uninstalled imageio-2.9.0
# Successfully installed imageio-2.4.1
# Downloading...
# From: https://drive.google.com/uc?id=18cBhKpkRflQmyXCVjy1DtVLIUnLPo2bO
# To: /content/pytorchcv-0.0.55-py2.py3-none-any.whl
# 100%|██████████| 391k/391k [00:00<00:00, 30.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1siAcM9uTEoLEeqKFxq5h-hjs4NoHS0SU
# To: /content/resnext.pth
# 100%|██████████| 92.3M/92.3M [00:00<00:00, 303MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1--68J6Ipny937AFjJ_AKjhFXFnvnGecV
# To: /content/xception.pth
# 100%|██████████| 87.8M/87.8M [00:00<00:00, 282MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FhJrGLBnnRw_nq0p58NUzlN2rZI9BAQa
# To: /content/blazeface.pth
# 100%|██████████| 420k/420k [00:00<00:00, 58.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oqK5yz5ZaWjLP9O_eXhvGL9RD6hOyS6d
# To: /content/anchors.npy
# 100%|██████████| 28.8k/28.8k [00:00<00:00, 18.0MB/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-41d698a2ed19> in <module>
#       1 get_ipython().system('sudo pip3 install imageio==2.4.1')
# ----> 2 from deepfake_detection import DeepFake_Utils
#       3 from moviepy.editor import *
#
# /usr/local/lib/python3.7/dist-packages/deepfake_detection/DeepFake_Utils.py in <module>
#      62 import torch.nn as nn
#      63 from pytube import YouTube
# ---> 64 from moviepy.editor import *
#      65 import torch.nn.functional as F
#      66 import torchvision.models as models
#
# /usr/local/lib/python3.7/dist-packages/moviepy/editor.py in <module>
#      24 # Checks to see if the user has set a place for their own version of ffmpeg
#      25 if os.getenv('FFMPEG_BINARY', 'ffmpeg-imageio') == 'ffmpeg-imageio':
# ---> 26     imageio.plugins.ffmpeg.download()
#      27
#      28 # Clips
#
# /usr/local/lib/python3.7/dist-packages/imageio/plugins/ffmpeg.py in download(directory, force_download)
#      36 )
#      37
# ---> 38
#      39 ISWIN = sys.platform.startswith("win")
#      40
#
# RuntimeError: imageio.ffmpeg.download() has been deprecated. Use 'pip install imageio-ffmpeg' instead.'
